# %% [markdown]
# <a href="https://colab.research.google.com/github/cite19000091long/ChatGLM-6B/blob/main/glm_finetune_test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %% [markdown]
# # 新段落

# %% [markdown]
# # 新段落

# %% [markdown]
# # 新段落

# %%
# !git clone https://github.com/cite19000091long/ChatGLM-6B.git
# Out:
# Cloning into 'ChatGLM-6B'...
# remote: Enumerating objects: 763, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 763 (delta 9), reused 12 (delta 7), pack-reused 747
# Receiving objects: 100% (763/763), 5.74 MiB | 4.14 MiB/s, done.
# Resolving deltas: 100% (428/428), done.

# %%
# %cd ChatGLM-6B
# Out:
# /content/ChatGLM-6B

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 40.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.6/416.6 kB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 83.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 kB 17.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.7 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm-6b", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm-6b", trust_remote_code=True).half().cuda()
model = model.eval()
response, history = model.chat(tokenizer, "你好", history=[])
print(response)
response, history = model.chat(tokenizer, "晚上睡不着应该怎么办", history=history)
print(response)
# Out:
# ...
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# WARNING:transformers_modules.THUDM.chatglm-6b.aa51e62ddc9c9f334858b0af44cf59b05c70148a.modeling_chatglm:The dtype of attention mask (torch.int64) is not bool
# 你好👋！我是人工智能助手 ChatGLM-6B，很高兴见到你，欢迎问我任何问题。
# 晚上睡不着可能会让人感到沮丧和焦虑，但以下是一些可能有用的技巧，可以帮助您入睡：
#
# 1. 创建一个舒适的睡眠环境：确保房间安静、黑暗、凉爽和舒适。如果可能的话，使用耳塞、眼罩和床罩等工具来确保舒适的睡眠环境。
#
# 2. 规律作息：保持规律的作息习惯，尽量在同一时间上床睡觉和起床。遵循固定的睡眠时间表，可以帮助身体建立一个正常的睡眠节律。
#
# 3. 放松身心：在睡前做些放松的活动，例如冥想、深呼吸、泡个热水澡或阅读一些轻松的书籍，有助于放松身心，减轻压力和焦虑。
#
# ...

# %%
import subprocess

env = os.environ.copy()
env['LC_ALL'] = 'C.UTF-8'
env['LANG'] = 'C.UTF-8'

cmd = "pip install rouge_chinese nltk jieba datasets"
subprocess.check_call(cmd, shell=True, env=env)
# Out:
# 0

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %cd ptuning
# !bash train.sh
# Out:
# [Errno 2] No such file or directory: 'ptuning'
# /content/ChatGLM-6B/ptuning
# 2023-04-12 12:58:59.533023: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/content/ChatGLM-6B/ptuning/main.py", line 429, in <module>
#     main()
#   File "/content/ChatGLM-6B/ptuning/main.py", line 58, in main
#     model_args, data_args, training_args = parser.parse_args_into_dataclasses()
#   File "/usr/local/lib/python3.9/dist-packages/transformers/hf_argparser.py", line 332, in parse_args_into_dataclasses
#     obj = dtype(**inputs)
#   File "<string>", line 113, in __init__
#   File "/usr/local/lib/python3.9/dist-packages/transformers/training_args.py", line 1227, in __post_init__
#     and (self.device.type != "cuda")
#   File "/usr/local/lib/python3.9/dist-packages/transformers/training_args.py", line 1659, in device
#     return self._setup_devices
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %cd ptuning
# !bash train.sh
# Out:
# [Errno 2] No such file or directory: 'ptuning'
# /content/ChatGLM-6B/ptuning
# 2023-04-12 12:59:32.711346: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/content/ChatGLM-6B/ptuning/main.py", line 429, in <module>
#     main()
#   File "/content/ChatGLM-6B/ptuning/main.py", line 58, in main
#     model_args, data_args, training_args = parser.parse_args_into_dataclasses()
#   File "/usr/local/lib/python3.9/dist-packages/transformers/hf_argparser.py", line 332, in parse_args_into_dataclasses
#     obj = dtype(**inputs)
#   File "<string>", line 113, in __init__
#   File "/usr/local/lib/python3.9/dist-packages/transformers/training_args.py", line 1227, in __post_init__
#     and (self.device.type != "cuda")
#   File "/usr/local/lib/python3.9/dist-packages/transformers/training_args.py", line 1659, in device
#     return self._setup_devices
# ...
